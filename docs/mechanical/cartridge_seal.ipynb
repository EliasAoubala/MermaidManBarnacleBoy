# %% [markdown]
# # Cartridge Seal Design

# %% [markdown]
# > Date
#
# > Author: Elias Aoubala

# %% [markdown]
# ## 1 - Background

# %% [markdown]
# This document contains the design and accomodation of the cartridge seal of the turbopump.

# %% [markdown]
# ## 2 - Cartidge Seal Selection

# %% [markdown]
# A Cartridge Seal from [Aliexpress](https://www.aliexpress.com/item/1005005584784739.html?gatewayAdapt=glo2fra#nav-specification) has been selected for the baseline design of the turbopump.
#
# Specifically, a 58B-25 has been selected, which looks something like this:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# The specific dimensions for the cartridge seal are as follows:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# In addition, this source indicates the following dimensions:
#
# ![image.png](attachment:image.png)
